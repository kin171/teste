# %%
! pip install plotly openpyxl numpy ipykernel nbformat
! pip install pandas
import pandas as pd
tabela = pd.read_csv('cancelamentos.csv')
# Out:
# ...
#   Using cached plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached numpy-2.0.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# ...
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# ...
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached rpds_py-0.19.0-cp312-none-win_amd64.whl.metadata (4.2 kB)
# ...
# Using cached plotly-5.22.0-py3-none-any.whl (16.4 MB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# ...

# %%
 pd.read_csv('cancelamentos.csv')
# Out:
#         CustomerID  idade    sexo  tempo_como_cliente  frequencia_uso  \
# 0              2.0   30.0  Female                39.0            14.0
# 1              3.0   65.0  Female                49.0             1.0
# 2              4.0   55.0  Female                14.0             4.0
# 3              5.0   58.0    Male                38.0            21.0
# 4              6.0   23.0    Male                32.0            20.0
# ...            ...    ...     ...                 ...             ...
# 308120    315234.0   32.0    Male                20.0            21.0
# 308121    315235.0   35.0  Female                29.0             9.0
# 308122    315236.0   22.0    Male                60.0            26.0
# 308123    315237.0   49.0    Male                36.0            17.0
# 308124    315238.0   46.0    Male                25.0             9.0
#
#         ligacoes_callcenter  dias_atraso assinatura duracao_contrato  \
# ...

# %%
import pandas as pd
import plotly.express as px




tabela =  pd.read_csv("teste5.CSV")
tabela = tabela.fillna(0)
display(tabela["Lamina (mm/h)"].value_counts())

grafico = px.histogram(tabela, x='Lamina (mm/h)', y = '')
grafico.show()



#! pip install sklearn
# Out:
# C:\Users\kin50\AppData\Local\Temp\ipykernel_25036\1063851169.py:7: DtypeWarning:
#
# Columns (37,38,39,42,43,44,47,49,50,54,55) have mixed types. Specify dtype option on import or set low_memory=False.
# Lamina (mm/h)
# 0.5      12329
# 0.500     7063
# 0.833     4055
# 0.833     3031
# -          682
# 0           73
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 11
#       8 tabela = tabela.fillna(0)
#       9 display(tabela["Lamina (mm/h)"].value_counts())
# ---> 11 grafico = px.histogram(tabela, x='Lamina (mm/h)', y = 'PROJETO')
#      12 grafico.show()
#      16 #! pip install sklearn
#
# ...
